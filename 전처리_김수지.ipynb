# %%
import numpy as np
import pandas as pd

# %%
사과 = pd.read_csv('사과.csv', encoding='euc-kr')
배 = pd.read_csv('배.csv', encoding='euc-kr')
배추 = pd.read_csv('배추.csv', encoding='euc-kr')
무 = pd.read_csv('무.csv', encoding='euc-kr')

# %%
배.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5248 entries, 0 to 5247
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   일련번호               5248 non-null   int64
#  1   시장/마트 번호           5248 non-null   int64
#  2   시장/마트 이름           5248 non-null   object
#  3   품목 번호              5248 non-null   int64
#  4   품목 이름              5248 non-null   object
#  5   실판매규격              5248 non-null   object
#  6   가격(원)              5248 non-null   int64
#  7   년도-월               5248 non-null   object
#  8   비고                 5235 non-null   object
#  9   시장유형 구분(시장/마트) 코드  5248 non-null   int64
#  10  시장유형 구분(시장/마트) 이름  5248 non-null   object
#  11  자치구 코드             5248 non-null   int64
#  12  자치구 이름             5248 non-null   object
#  13  점검일자               5248 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 574.1+ KB

# %%
배['품목 번호'].unique()
# Out:
# array([ 27, 306, 284, 276, 248,  26, 175, 307], dtype=int64)

# %%
#배 품목번호 26

# %%
p1 = (배['품목 번호'] == 26)
배[p1]
# Out:
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호        품목 이름           실판매규격  \
# 4660  1713242       110    이마트 신도림점     26        배(신고)             1포기
# 4687  1712548        84     청량리종합시장     26  배(신고, 600g)      1포기(3.5kg)
# 4725  1713191       109      고척근린시장     26            배             1포기
# 4744  1713547       215      청담삼익시장     26        배(신고)             1포기
# 4746  1713581        45   롯데백화점 강남점     26        배(신고)             1포기
# 4747  1713598       216        도곡시장     26        배(신고)             1포기
# 4761  1713852        15     이마트 미아점     26  배(신고, 600g)            1포기
# 4762  1713869        16   현대백화점 미아점     26  배(신고, 600g)  1포기 (2,5~3kg )
# 4763  1713886        14      장위골목시장     26  배(신고, 600g)  1 포기(2,5~3kg )
# 4824  1715075        51   NC백화점 불광점     26        배(신고)             1포기
# 4926  1717012       227  NC백화점 신구로점     26            배             1포기
#
#       가격(원)     년도-월                     비고  시장유형 구분(시장/마트) 코드  \
# ...

# %%
배[p2]['실판매규격'].nunique()
# Out:
# 245

# %%
p3 = (배['품목 번호'] == 175)
배[p3]['실판매규격'].nunique()
# Out:
# 1

# %%
p4 = (배['품목 번호'] == 248)
배[p4]['실판매규격'].nunique()
# Out:
# 2

# %%
p5 = (배['품목 번호'] == 276)
배[p5]['실판매규격'].nunique()
# Out:
# 125

# %%
p6 = (배['품목 번호'] == 284)
배[p6]['실판매규격'].nunique()
# Out:
# 2

# %%
p7 = (배['품목 번호'] == 306)
배[p7]['실판매규격'].nunique()
# Out:
# 176

# %%
p8 = (배['품목 번호'] == 307)
배[p8]['실판매규격'].nunique()
# Out:
# 3

# %%
#배 품목번호 27

# %%
p2 = (배['품목 번호'] == 27)
배[p2]['실판매규격'].unique()
# Out:
# array(['1개 (600g)', '1박스(2500g)', '1박스(2650g)', '1개(812g)', '1봉지(2.6kg)',
#        '1봉지(1.7kg)', '1개(739g)', '1개(700g)', '1개(600g)', '1개(650g)',
#        '1개(750g)', '1개', '1개 (700g)', '1개(450g)', '1개(836g)',
#        '1상자(6개)3000g', '1상자(5개)3000g', '1개500g', '1봉(3개)1778g',
#        '1개(697g)', '1봉지(2.4kg)', '1봉지(1.5kg)', '1개(789g)', '1개(550g)',
#        '1개(630g)', '1개(500g)', '1개[ 600g]', '1개 (800g)', '1봉 1800g4',
#        '1개(893g)', '1봉(3개)1924g', '1개580g', '1상자(4개)3000g', '1봉(3개)2218g',
#        '1상자(9개)3000g6', '1개600g', '1개(580g)', '1개 784g', '1봉지 2.3kg',
#        '1봉지 1.7kg', '1개(852g)', '1개716g', '1봉(3개)1984g', '1개550g',
#        '1개 699g', '1봉지 1.3kg', '1개 769g', '1개(510g)', '1개(610g)',
#        '2개1300g', '1개(832g)', '1봉지 1.4kg', '1개 768g', '1봉지 2.5kg',
#        '1개690g', '1봉(3개)1954g', '1상자(7개)5000g', '1개 (500g)', '2개1860g',
#        '1개684g', '1상자(7개)5000g   ', '1봉(3개)2000g', '1개 821g', '1팩1.7kg',
#        '1팩 2.2kg', '1개 810g', '1개(제수용,특)', '1개(제수용)', '1개(680g)',
# ...

# %%
#'1박스(2500g)'
배_27 = 배[p2]
c = (배_27['실판매규격']=='1박스(2500g)')
index = [배_27[c].index]
배_27[c]
# Out:
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름       실판매규격  가격(원)     년도-월  \
# 25    1631698        91     동원시장     27     배  1박스(2500g)  15500  2021-01
# 27    1631730        90     우림시장     27     배  1박스(2500g)  16000  2021-01
# 222   1635049        90     우림시장     27     배  1박스(2500g)  18000  2021-01
# 224   1635081        91     동원시장     27     배  1박스(2500g)  16000  2021-01
# 407   1638522        90     우림시장     27     배  1박스(2500g)  17000  2021-02
# 409   1638554        91     동원시장     27     배  1박스(2500g)  17000  2021-02
# 423   1641655        91     동원시장     27     배  1박스(2500g)  18000  2021-02
# 424   1641671        90     우림시장     27     배  1박스(2500g)  18000  2021-02
# 832   1645130        90     우림시장     27     배  1박스(2500g)  18000  2021-03
# 834   1645162        91     동원시장     27     배  1박스(2500g)  18000  2021-03
# 1039  1648798        91     동원시장     27     배  1박스(2500g)  18000  2021-03
# 1042  1648846        90     우림시장     27     배  1박스(2500g)  17500  2021-03
# ...

# %%
index
# Out:
# [Int64Index([  25,   27,  222,  224,  407,  409,  423,  424,  832,  834, 1039,
#              1042, 1214, 1215, 1500, 1501, 1622, 1623, 1828, 1830, 2009, 2281,
#              2484, 2668, 2789],
#             dtype='int64')]

# %%
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4.16)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 25    1631698        91     동원시장     27     배  1박스(2500g)  3725.0  2021-01
# 27    1631730        90     우림시장     27     배  1박스(2500g)  3846.0  2021-01
# 222   1635049        90     우림시장     27     배  1박스(2500g)  4326.0  2021-01
# 224   1635081        91     동원시장     27     배  1박스(2500g)  3846.0  2021-01
# 407   1638522        90     우림시장     27     배  1박스(2500g)  4086.0  2021-02
# 409   1638554        91     동원시장     27     배  1박스(2500g)  4086.0  2021-02
# ...

# %%
#'1박스(2650g)'
c = (배_27['실판매규격']=='1박스(2650g)')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4.416)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 26    1631714        94  홈플러스 면목점     27     배  1박스(2650g)  3847.0  2021-01
# 28    1631746        92   이마트 상봉점     27     배  1박스(2650g)  3618.0  2021-01
# 221   1635033        94  홈플러스 면목점     27     배  1박스(2650g)  4300.0  2021-01
# 223   1635065        92   이마트 상봉점     27     배  1박스(2650g)  3845.0  2021-01
# 406   1638506        94  홈플러스 면목점     27     배  1박스(2650g)  4073.0  2021-02
# 408   1638538        92   이마트 상봉점     27     배  1박스(2650g)  3980.0  2021-02
# ...

# %%
#'1봉지(2.6kg)'
c = (배_27['실판매규격']=='1봉지(2.6kg)')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4.3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#        일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 34  1631847        28  홈플러스 방학점     27     배  1봉지(2.6kg)  3486.0  2021-01
#
#                비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 34  국내산.신고.1봉지4개입                  2              대형마트  320000    도봉구
#
#           점검일자
# 34  2021-01-28

# %%
# '1봉지(1.7kg)'
c = (배_27['실판매규격']=='1봉지(1.7kg)')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#        일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 35  1631864        27  이마트 창동점     27     배  1봉지(1.7kg)  4416.0  2021-01
#
#                비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 35  국내산.신고.1봉지2개입                  2              대형마트  320000    도봉구
#
#           점검일자
# 35  2021-01-28

# %%
#  '1상자(6개)3000g'
c = (배_27['실판매규격']=='1상자(6개)3000g')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/5)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호 품목 이름         실판매규격   가격(원)  \
# 77    1632585       140  하나로클럽 양재점     27     배  1상자(6개)3000g  3100.0
# 165   1634079       140  하나로클럽 양재점     27     배  1상자(6개)3000g  3100.0
# 678   1642661       140  하나로클럽 양재점     27     배  1상자(6개)3000g  3560.0
# 881   1646035       140  하나로클럽 양재점     27     배  1상자(6개)3000g  3360.0
# 968   1647585       140  하나로클럽 양재점     27     배  1상자(6개)3000g  3360.0
# 1102  1649915       140  하나로클럽 양재점     27     배  1상자(6개)3000g  3560.0
# ...

# %%
#   '1상자(5개)3000g'
c = (배_27['실판매규격']== '1상자(5개)3000g')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/5)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름         실판매규격   가격(원)  \
# 78    1632602       200  뉴코아아울렛 강남점     27     배  1상자(5개)3000g  3580.0
# 775   1644385       140   하나로클럽 양재점     27     배  1상자(5개)3000g  3560.0
# 1008  1648264       140   하나로클럽 양재점     27     배  1상자(5개)3000g  3360.0
# 1607  1658512       140   하나로클럽 양재점     27     배  1상자(5개)3000g  3760.0
# 1723  1660366       140   하나로클럽 양재점     27     배  1상자(5개)3000g  3760.0
# 2011  1665366       140   하나로클럽 양재점     27     배  1상자(5개)3000g  3760.0
# ...

# %%
#   '1봉(3개)1778g'
c = (배_27['실판매규격']== '1봉(3개)1778g')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#        일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 80  1632636       218  신세계백화점 강남점     27     배  1봉(3개)1778g  7266.0  2021-01
#
#         비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 80  국내산/신고                  2              대형마트  650000    서초구  2021-01-28

# %%
#'1봉지(2.4kg)'
c = (배_27['실판매규격']== '1봉지(2.4kg)')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 130  1633485        28  홈플러스 방학점     27     배  1봉지(2.4kg)  3747.0  2021-01
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 130  국내산.신고.1봉지4개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 130  2021-01-28

# %%
#'1봉지(1.5kg)'
c = (배_27['실판매규격']== '1봉지(1.5kg)')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.5)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 131  1633502        27  이마트 창동점     27     배  1봉지(1.5kg)  5000.0  2021-01
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 131  국내산.신고.1봉지2개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 131  2021-01-28

# %%
#'1봉 1800g4'
c = (배_27['실판매규격']== '1봉 1800g4')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 156  1633927       110  이마트 신도림점     27     배  1봉 1800g4  3633.0  2021-01
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 156  국내산,신고                  2              대형마트  530000    구로구  2021-01-28

# %%
#'1봉(3개)1924g'
c = (배_27['실판매규격']== '1봉(3개)1924g')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 166  1634096       218  신세계백화점 강남점     27     배  1봉(3개)1924g  7266.0  2021-01
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 166  국내산/신고                  2              대형마트  650000    서초구  2021-01-28

# %%
#'1상자(4개)3000g'
c = (배_27['실판매규격']== '1상자(4개)3000g')
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름         실판매규격   가격(원)  \
# 168   1634129       200  뉴코아아울렛 강남점     27     배  1상자(4개)3000g  4975.0
# 213   1634898       200  뉴코아아울렛 강남점     27     배  1상자(4개)3000g  4975.0
# 302   1636429       140   하나로클럽 양재점     27     배  1상자(4개)3000g  3875.0
# 1485  1656341       140   하나로클럽 양재점     27     배  1상자(4개)3000g  4200.0
# 1574  1657891       140   하나로클럽 양재점     27     배  1상자(4개)3000g  4200.0
# 2210  1668691       140   하나로클럽 양재점     27     배  1상자(4개)3000g  4700.0
# ...

# %%
#'1봉(3개)2218g'
c = (배_27['실판매규격']== '1봉(3개)2218g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 214  1634915       218  신세계백화점 강남점     27     배  1봉(3개)2218g  7266.0  2021-01
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 214  국내산/신고                  2              대형마트  650000    서초구  2021-01-28

# %%
# '1상자(9개)3000g6'
c = (배_27['실판매규격']== '1상자(9개)3000g6' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/5)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호   시장/마트 이름  품목 번호 품목 이름          실판매규격   가격(원)  \
# 215  1634931       140  하나로클럽 양재점     27     배  1상자(9개)3000g6  3100.0
#
#         년도-월         비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 215  2021-01  국내산/아산/신고                  2              대형마트  650000    서초구
#
#            점검일자
# 215  2021-01-28

# %%
# '1봉지 2.3kg'
c = (배_27['실판매규격']== '1봉지 2.3kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 263  1635743        28  홈플러스 방학점     27     배  1봉지 2.3kg  4436.0  2021-01
#
#                  비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 263  국내산,신고 1봉지 3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 263  2021-01-28

# %%
# '1봉지 1.7kg'
c = (배_27['실판매규격']== '1봉지 1.7kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 264  1635760        27  이마트 창동점     27     배  1봉지 1.7kg  3851.0  2021-01
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 264  국내산,신고 1봉지4개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 264  2021-01-28

# %%
# '1봉(3개)1984g'
c = (배_27['실판매규격']== '1봉(3개)1984g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 301  1636413       218  신세계백화점 강남점     27     배  1봉(3개)1984g  7600.0  2021-01
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 301  국내산/신고                  2              대형마트  650000    서초구  2021-01-28

# %%
#'1봉지 1.3kg'
c = (배_27['실판매규격']== '1봉지 1.3kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.16)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 341  1637088        27   이마트 창동점     27     배  1봉지 1.3kg  5972.0  2021-01
# 343  1637122        28  홈플러스 방학점     27     배  1봉지 1.3kg  7402.0  2021-01
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 341  국내산.신고 1봉지2개입                  2              대형마트  320000    도봉구
# 343  국내산.신고 1봉지4개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 341  2021-01-28
# 343  2021-01-28

# %%
# '2개1300g'
c = (배_27['실판매규격']== '2개1300g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름    실판매규격   가격(원)     년도-월  \
# 366  1637521       110  이마트 신도림점     27     배  2개1300g  4490.0  2021-01
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 366  국내산,신고                  2              대형마트  530000    구로구  2021-01-28

# %%
# '1봉지 1.4kg'
c = (배_27['실판매규격']== '1봉지 1.4kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 459  1638655        27  이마트 창동점     27     배  1봉지 1.4kg  5434.0  2021-02
# 800  1645263        27  이마트 창동점     27     배  1봉지 1.4kg  5565.0  2021-03
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 459  국내산.신고.1봉지3개입                  2              대형마트  320000    도봉구
# 800  국내산.신고.1봉지3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 459  2021-02-25
# 800  2021-03-11

# %%
# '1봉지 2.5kg'
c = (배_27['실판매규격']== '1봉지 2.5kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4.16)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 461  1638689        28  홈플러스 방학점     27     배  1봉지 2.5kg  3603.0  2021-02
#
#                비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 461  국내산.신고.1망3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 461  2021-02-25

# %%
#  '1봉(3개)1954g'
c = (배_27['실판매규격']==  '1봉(3개)1954g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 495  1639275       218  신세계백화점 강남점     27     배  1봉(3개)1954g  7600.0  2021-02
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 495  국내산/신고                  2              대형마트  650000    서초구  2021-02-25

# %%
#  '1상자(7개)5000g'
c = (배_27['실판매규격']==  '1상자(7개)5000g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/7)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호   시장/마트 이름  품목 번호 품목 이름         실판매규격   가격(원)     년도-월  \
# 496  1639291       140  하나로클럽 양재점     27     배  1상자(7개)5000g  3542.0  2021-02
#
#             비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 496  국내산/천안/신고                  2              대형마트  650000    서초구  2021-02-25

# %%
# '2개1860g'
c = (배_27['실판매규격']==  '2개1860g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름    실판매규격   가격(원)     년도-월  \
# 564  1640579       110  이마트 신도림점     27     배  2개1860g  4490.0  2021-02
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 564  국내산,신고                  2              대형마트  530000    구로구  2021-02-25

# %%
# '1상자(7개)5000g   '
c = (배_27['실판매규격']==  '1상자(7개)5000g   ' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/7)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호   시장/마트 이름  품목 번호 품목 이름            실판매규격   가격(원)  \
# 575  1640766       140  하나로클럽 양재점     27     배  1상자(7개)5000g     3542.0
#
#         년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 575  2021-02  국내산/신고                  2              대형마트  650000    서초구
#
#            점검일자
# 575  2021-02-25

# %%
# '1봉(3개)2000g'
c = (배_27['실판매규격']==  '1봉(3개)2000g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 576   1640783       218  신세계백화점 강남점     27     배  1봉(3개)2000g  7600.0
# 1100  1649882       218  신세계백화점 강남점     27     배  1봉(3개)2000g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 576   2021-02  국내산/신고                  2              대형마트  650000    서초구
# 1100  2021-03  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 576   2021-02-25
# 1100  2021-03-25

# %%
# '1팩1.7kg'
c = (배_27['실판매규격']==  '1팩1.7kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름    실판매규격   가격(원)     년도-월  \
# 595  1641104        28  홈플러스 방학점     27     배  1팩1.7kg  6537.0  2021-02
#
#                비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 595  국내산.신고.1팩3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 595  2021-02-25

# %%
# '1팩1.7kg'
c = (배_27['실판매규격']==  '1팩1.7kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]

# %%
#'1팩 2.2kg'
c = (배_27['실판매규격']==  '1팩 2.2kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3.66)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름     실판매규격   가격(원)     년도-월  \
# 596  1641121        27  이마트 창동점     27     배  1팩 2.2kg  5437.0  2021-02
#
#               비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 596  국내산.신고1팩3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 596  2021-02-25

# %%
#'1봉(3개)1890g'
c = (배_27['실판매규격']==  '1봉(3개)1890g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 680   1642695       218  신세계백화점 강남점     27     배  1봉(3개)1890g  7600.0
# 1886  1663210       218  신세계백화점 강남점     27     배  1봉(3개)1890g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 680   2021-02  국내산/신고                  2              대형마트  650000    서초구
# 1886  2021-05  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 680   2021-02-25
# 1886  2021-05-27

# %%
#'1팩 1.7kg'
c = (배_27['실판매규격']==  '1팩 1.7kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름     실판매규격   가격(원)     년도-월  \
# 700  1643034        28  홈플러스 방학점     27     배  1팩 1.7kg  6537.0  2021-02
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 700  국내산.신고.1팩.3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 700  2021-02-25

# %%
#'1팩 2kg'
c = (배_27['실판매규격']==  '1팩 2kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3.3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름   실판매규격   가격(원)     년도-월  \
# 701  1643051        27  이마트 창동점     27     배  1팩 2kg  6030.0  2021-02
#
#                비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 701  국내산.신고.1팩3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 701  2021-02-25

# %%
#'1봉지 1,7kg'
c = (배_27['실판매규격']== '1봉지 1,7kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.83)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 730  1643544        28  홈플러스 방학점     27     배  1봉지 1,7kg  6003.0  2021-02
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 730  국내산.신고.1봉지3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 730  2021-02-25

# %%
#'1봉지 1.5kg'
c = (배_27['실판매규격']== '1봉지 1.5kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.5)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 731  1643561        27  이마트 창동점     27     배  1봉지 1.5kg  5120.0  2021-02
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 731  국내산.신고.1봉지3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 731  2021-02-25

# %%
#1봉(3개)2056g'
c = (배_27['실판매규격']==  '1봉(3개)2056g' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 776  1644402       218  신세계백화점 강남점     27     배  1봉(3개)2056g  7600.0  2021-02
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 776  국내산/신고                  2              대형마트  650000    서초구  2021-02-25

# %%
#'1봉지 2.4kg'
c = (배_27['실판매규격']==  '1봉지 2.4kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 802  1645297        28  홈플러스 방학점     27     배  1봉지 2.4kg  4247.0  2021-03
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 802  국내산.신고.1봉지4개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 802  2021-03-11

# %%
 #'1봉지 196kg'
c = (배_27['실판매규격']==  '1봉지 196kg' )
index = [배_27[c].index]
배_27[c]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3.16)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 804  1646897        27  이마트 창동점     27     배  1봉지 196kg  4588.0  2021-03
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 804  국내산.신고.1봉지2개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 804  2021-03-11

# %%
 #'1봉지 1.6kg'
c = (배_27['실판매규격']== '1봉지 1.6kg' )
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름      실판매규격   가격(원)     년도-월  \
# 806  1646931        28  홈플러스 방학점     27     배  1봉지 1.6kg  6330.0  2021-03
#
#                 비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 806  국내산.신고.1봉지3개입                  2              대형마트  320000    도봉구
#
#            점검일자
# 806  2021-03-11

# %%
 #'1봉(3개)g'
c = (배_27['실판매규격']== '1봉(3개)g' )
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름    실판매규격   가격(원)     년도-월  \
# 880  1646019       218  신세계백화점 강남점     27     배  1봉(3개)g  7600.0  2021-03
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 880  국내산/신고                  2              대형마트  650000    서초구  2021-03-25

# %%
#'3개1봉2kg'
c = (배_27['실판매규격']== '3개1봉2kg')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름    실판매규격   가격(원)     년도-월  \
# 953  1647330       110  이마트 신도림점     27     배  3개1봉2kg  4266.0  2021-03
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 953  국내산,신고                  2              대형마트  530000    구로구  2021-03-25

# %%
#'1봉(3개)1878g'
c = (배_27['실판매규격']== '1봉(3개)1878g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 970  1647619       218  신세계백화점 강남점     27     배  1봉(3개)1878g  7600.0  2021-03
#
#          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 970  국내산/신고                  2              대형마트  650000    서초구  2021-03-25

# %%
# '1봉(3개)1980g'
c = (배_27['실판매규격']==  '1봉(3개)1980g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 1009  1648281       218  신세계백화점 강남점     27     배  1봉(3개)1980g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1009  2021-03  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 1009  2021-03-25

# %%
#  '1박스(2700g)'
c = (배_27['실판매규격']==  '1박스(2700g)')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/4.5)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 1213  1651636        94  홈플러스 면목점     27     배  1박스(2700g)  3775.0  2021-04
# 1499  1656579        94  홈플러스 면목점     27     배  1박스(2700g)  4220.0  2021-04
# 1621  1658749        94  홈플러스 면목점     27     배  1박스(2700g)  4220.0  2021-04
# 1829  1662220        94  홈플러스 면목점     27     배  1박스(2700g)  3997.0  2021-05
# 2007  1665301        94  홈플러스 면목점     27     배  1박스(2700g)  3775.0  2021-05
# 2282  1669975        91      동원시장     27     배  1박스(2700g)  3555.0  2021-06
# ...

# %%
# '1봉(3개)1982g'
c = (배_27['실판매규격']==  '1봉(3개)1982g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 1218  1651717       218  신세계백화점 강남점     27     배  1봉(3개)1982g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1218  2021-04  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 1218  2021-04-29

# %%
#  '30개(1.8kg)'
c = (배_27['실판매규격']==  '30개(1.8kg)')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 1366  1654295       110  이마트 신도림점     27     배  30개(1.8kg)  4266.0  2021-04
#
#           비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 1366  국내산,신고                  2              대형마트  530000    구로구  2021-04-29

# %%
#'1봉(3개)1896g'
c = (배_27['실판매규격']==  '1봉(3개)1896g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 1377  1654482       218  신세계백화점 강남점     27     배  1봉(3개)1896g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1377  2021-04  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 1377  2021-04-29

# %%
# '1봉(3개)1962g'
c = (배_27['실판매규격']==  '1봉(3개)1962g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 1484  1656325       218  신세계백화점 강남점     27     배  1봉(3개)1962g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1484  2021-04  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 1484  2021-04-29

# %%
#   '1봉(3개)1900g'
c = (배_27['실판매규격']== '1봉(3개)1900g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 1576  1657925       218  신세계백화점 강남점     27     배  1봉(3개)1900g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1576  2021-04  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 1576  2021-04-29

# %%
#'1봉(3개)1928g'
c = (배_27['실판매규격']== '1봉(3개)1928g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)  \
# 1608  1658529       218  신세계백화점 강남점     27     배  1봉(3개)1928g  7600.0
# 1722  1660350       218  신세계백화점 강남점     27     배  1봉(3개)1928g  7600.0
#
#          년도-월      비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1608  2021-04     국내산                  2              대형마트  650000    서초구
# 1722  2021-05  국내산/신고                  2              대형마트  650000    서초구
#
#             점검일자
# 1608  2021-04-29
# 1722  2021-05-27

# %%
list3 = [ '1봉(3개)1915g', '1봉(3개)1880g', '1봉(3개)1930g','1팩(1.7kg)3개', '1봉(1.7kg)3개',  '1팩(1957g)3개']

# %%
d = (배_27['실판매규격'].isin(list3))
배_27.loc[d,'가격(원)'] = (배_27.loc[d,'가격(원)']/3)
배_27.loc[d,'가격(원)'].astype('int')
배_27[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름        실판매규격        가격(원)  \
# 1972  1664712       218  신세계백화점 강남점     27     배  1봉(3개)1915g  7600.000000
# 2013  1665400       218  신세계백화점 강남점     27     배  1봉(3개)1880g  7600.000000
# 2165  1667931       218  신세계백화점 강남점     27     배  1봉(3개)1930g  7600.000000
# 3349  1683636        86   홈플러스 동대문점     27     배  1팩(1.7kg)3개  6330.000000
# 3357  1687026        86   홈플러스 동대문점     27     배  1봉(1.7kg)3개  6996.666667
# 3361  1688721        86   홈플러스 동대문점     27     배  1팩(1957g)3개  6996.666667
#
# ...

# %%
list2 = [ '1봉(2개)1582g',  '1봉(2개)1650g', '1봉(2개)1136g',  '1봉(2개)1700g','1봉(2개)1600g','1봉(2개)1320g',  '1봉(2개)1684g','1봉(2개)1710g',  '1봉(2개)1,678g', '1봉(2개)1328g', '1개(1288g)2개','1팩(1244g)2개',  '1팩(1367g)2개','1팩(1230g)2개']
d2 = (배_27['실판매규격'].isin(list2))
배_27.loc[d2,'가격(원)'] = (배_27.loc[d2,'가격(원)']/2)
배_27.loc[d2,'가격(원)'].astype('int')
배_27[d2]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름         실판매규격    가격(원)  \
# 2211  1668708       218  신세계백화점 강남점     27     배   1봉(2개)1582g  11400.0
# 2376  1671747       218  신세계백화점 강남점     27     배   1봉(2개)1650g  11400.0
# 2377  1671763       228      방배종합시장     27     배   1봉(2개)1136g   5000.0
# 2469  1674388       218  신세계백화점 강남점     27     배   1봉(2개)1700g  11400.0
# 2520  1675180       218  신세계백화점 강남점     27     배   1봉(2개)1700g  11400.0
# 2605  1676688       218  신세계백화점 강남점     27     배   1봉(2개)1600g  11400.0
# ...

# %%
list3000 = ['1박스(3000g)','1박스(3,000g)','1상자(6개)3kg', '1박스(3kg)5개' ]
d3000 = (배_27['실판매규격'].isin(list3000))
배_27.loc[d3000,'가격(원)'] = (배_27.loc[d3000,'가격(원)']/5)
배_27.loc[d3000,'가격(원)'].astype('int')
배_27[d3000]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 2667  1677791        94   홈플러스 면목점     27     배   1박스(3000g)  4798.0  2021-07
# 2787  1679957        94   홈플러스 면목점     27     배   1박스(3000g)  4798.0  2021-07
# 2994  1683704        94   홈플러스 면목점     27     배  1박스(3,000g)  5198.0  2021-08
# 3044  1684584       140  하나로클럽 양재점     27     배   1상자(6개)3kg  4360.0  2021-08
# 3353  1685280        86  홈플러스 동대문점     27     배   1박스(3kg)5개  4598.0  2021-08
# 3589  1694060        94   홈플러스 면목점     27     배   1박스(3000g)  3998.0  2021-09
# ...

# %%
list4 = ['1팩 3~4', '1팩 4개', '1팩3~4', '1팩 3~4개','1박스(2,650g)', '1박스(2,500g)', '1박스(2,700g)','1봉(2.5kg)']
d4 = (배_27['실판매규격'].isin(list4))
배_27.loc[d4,'가격(원)'] = (배_27.loc[d4,'가격(원)']/4)
배_27.loc[d4,'가격(원)'].astype('int')
배_27[d4]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호 품목 이름        실판매규격   가격(원)     년도-월  \
# 2995  1683720        90      우림시장     27     배  1박스(2,650g)  6000.0  2021-08
# 2996  1683736        92   이마트 상봉점     27     배  1박스(2,500g)  6495.0  2021-08
# 2997  1683752        91      동원시장     27     배  1박스(2,700g)  6000.0  2021-08
# 3298  1689384        40  홈플러스 등촌점     27     배    1봉(2.5kg)  4497.5  2021-08
# 4240  1698921         6   이마트 용산점     27     배       1팩 3~4  3200.0  2021-10
# 4247  1700596         6   이마트 용산점     27     배        1팩 4개  2700.0  2021-10
# ...

# %%
#'1봉(2kg)'
c = (배_27['실판매규격']==  '1봉(2kg)')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/3.3)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름    실판매규격   가격(원)     년도-월  \
# 3296  1689350        42  이마트 가양점     27     배  1봉(2kg)  3878.0  2021-08
# 3337  1690926        42  이마트 가양점     27     배  1봉(2kg)  3878.0  2021-08
#
#               비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 3296  국내산,원황햇배3개                  2              대형마트  500000    강서구
# 3337  국내산,원황햇배3개                  2              대형마트  500000    강서구
#
#             점검일자
# 3296  2021-08-26
# 3337  2021-08-26

# %%
#'1570개g'
c = (배_27['실판매규격']==  '1570개g')
index = [배_27[c].index]
for i in index:
    배_27.loc[i, '가격(원)'] = (배_27.loc[i, '가격(원)']/2.6)
    배_27.loc[i, '가격(원)'] = 배_27.loc[i, '가격(원)'].astype('int')
배_27[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름   실판매규격   가격(원)     년도-월  \
# 2012  1665383       228   방배종합시장     27     배  1570개g  1923.0  2021-05
#
#           비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 2012  국내산/신고                  1              전통시장  650000    서초구  2021-05-27

# %%
배_27
# Out:
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호 품목 이름       실판매규격   가격(원)     년도-월  \
# 0     1636108       226    롯데마트 구로점     27     배   1개 (600g)  1590.0  2021-01
# 25    1631698        91        동원시장     27     배  1박스(2500g)  3725.0  2021-01
# 26    1631714        94    홈플러스 면목점     27     배  1박스(2650g)  3847.0  2021-01
# 27    1631730        90        우림시장     27     배  1박스(2500g)  3846.0  2021-01
# 28    1631746        92     이마트 상봉점     27     배  1박스(2650g)  3618.0  2021-01
# ...       ...       ...         ...    ...   ...         ...     ...      ...
# 5212  1723293        32        영천시장     27     배    1개(530g)  2000.0  2021-12
# 5213  1723327        33   현대백화점 신촌점     27     배    1개(630g)  6700.0  2021-12
# 5217  1723480       123   홈플러스 월드컵점     27     배    1개(500g)  4497.0  2021-12
# 5225  1723817       227  NC백화점 신구로점     27     배      1개600g  3300.0  2021-12
# 5230  1723986        19      대림중앙시장     27     배    1개(600g)  3000.0  2021-12
#
# ...

# %%
#품목번호 175 -> drop해야할듯

# %%
p3 = (배['품목 번호'] == 175)
배[p3]
# Out:
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호 품목 이름         실판매규격  가격(원)     년도-월  \
# 4685  1712514        86  홈플러스 동대문점    175     배  1포기(2.5kg이상)   3190  2021-12
#
#        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 4685  국내산                  2              대형마트  230000   동대문구  2021-12-30

# %%
#품목 번호 248 -> 안바꿔도 됨

# %%
p4 = (배['품목 번호'] == 248)
배_248 = 배[p4]

# %%
#품목 번호 276

# %%
p5 = (배['품목 번호'] == 276)
배[p5]['실판매규격'].unique()
# Out:
# array(['1개(650g)', '1개', '1개(600g)', '1봉(2.5kg)', '1팩(1.6kg)',
#        '1봉(1.2kg)', '1봉(1.8kg)', '1개(800g)', '1봉(1.45kg)', '1개(670g)',
#        '1봉(1.9kg)', '1봉(1.6kg)', '1개(810g)', '1봉(1.1kg)', '1봉(1.4kg)',
#        '1개(73.g)', '1봉(1.7kg)', '1봉(1.27kg)', '1개(730g)', '1봉(1.5kg)',
#        '1개(630g)', '1팩(1.7kg)', '1팩(2.2kg)', '1봉(1.28kg)', '1개(710g)',
#        '1봉(2kg)', '1봉(1.3kg)', '1봉(1.55kg)', '1개(620g)', '1봉(1.25kg)',
#        '1개(384g)', '1개(700g)', '1개(740g)', '1개(900g)', '1봉(1kg)',
#        '1개(880g)', '1개(840g)', '1개(500g)', '1봉(1.26kg)', '1개(850g)',
#        '1봉(1.95kg)', '1개(890g)', '1개(780g)', '1봉(1.85kg)', '1봉(2.2kg)',
#        '1봉(2.3kg)', '1개(820g)', '1개(760g)', '1봉(2.1kg)', '1개(550g)',
#        '1개(765g)', '1개 (600g)', '1봉(2.4kg)', '1개(540g)', '1개(540g',
#        '1봉지4개', '1개(640g)', '1개(930g)', '1개,(480g)', '1팩(1.2kg)',
#        '1개(510g)', '1봉(1,8kg)', '1봉(4개)', '1개(480g)', '1개, 600g',
#        '1개(830g)', '1봉(2.5k)', '1봉(1.56kg)', '1개,600g', '550g',
# ...

# %%
배_276 = 배[p5]

# %%
list=['1봉(2.5kg)', '1봉(2.3kg)', '1봉(2.4kg)', '1봉(2.5k)', '1박스(2650g)', '1박스(2700g)']
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/4.16)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호  품목 이름       실판매규격        가격(원)  \
# 58    1632263        40   홈플러스 등촌점    276  배(신고)   1봉(2.5kg)  3603.365385
# 152   1633859        40   홈플러스 등촌점    276  배(신고)   1봉(2.5kg)  3603.365385
# 232   1635216        40   홈플러스 등촌점    276  배(신고)   1봉(2.5kg)  3603.365385
# 363   1637470        40   홈플러스 등촌점    276  배(신고)   1봉(2.5kg)  3843.750000
# 621   1641622        40   홈플러스 등촌점    276  배(신고)   1봉(2.5kg)  4084.134615
# 862   1645713        40   홈플러스 등촌점    276  배(신고)   1봉(2.5kg)  4084.134615
# ...

# %%
list=['1팩(1.6kg)','1봉(1.6kg)','1봉(1.55kg)','1봉(1.56kg)','1봉(1.7kg)','1팩(1.7kg)','1봉(1.5kg)' ]
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/2.6)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호  품목 이름       실판매규격        가격(원)  \
# 60    1632297        42    이마트 가양점    276  배(신고)   1팩(1.6kg)  4807.692308
# 150   1633825        42    이마트 가양점    276  배(신고)   1팩(1.6kg)  4807.692308
# 172   1634197        44    이마트 역삼점    276  배(신고)   1봉(1.6kg)  6500.000000
# 383   1637809        44    이마트 역삼점    276  배(신고)   1봉(1.7kg)  4538.461538
# 485   1639105        40   홈플러스 등촌점    276  배(신고)   1봉(1.7kg)  7115.384615
# 501   1639376        44    이마트 역삼점    276  배(신고)   1봉(1.5kg)  4538.461538
# ...

# %%
list=['1봉(1.2kg)', '1봉(1.1kg)',  '1봉(1.27kg)','1봉(1.3kg)',  '1봉(1.25kg)','1봉(1.26kg)','1팩(1.2kg)','1팩(1200g)','1봉(1.28kg)']
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/2)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호  품목 이름       실판매규격    가격(원)  \
# 81    1632652       215      청담삼익시장    276  배(신고)   1봉(1.2kg)   4950.0
# 169   1634146       215      청담삼익시장    276  배(신고)   1봉(1.2kg)   4950.0
# 217   1634965       215      청담삼익시장    276  배(신고)   1봉(1.2kg)   4950.0
# 220   1635016        44     이마트 역삼점    276  배(신고)   1봉(1.1kg)   3990.0
# 361   1637436        42     이마트 가양점    276  배(신고)   1봉(1.2kg)   6450.0
# 380   1637758       215      청담삼익시장    276  배(신고)   1봉(1.2kg)   4950.0
# ...

# %%
list=[ '1봉(1.8kg)', '1봉(1.85kg)',  '1봉(1,8kg)' ]
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/3)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호  품목 이름       실판매규격        가격(원)  \
# 82    1632669        45  롯데백화점 강남점    276  배(신고)   1봉(1.8kg)  6600.000000
# 615   1641520        45  롯데백화점 강남점    276  배(신고)   1봉(1.8kg)  8166.666667
# 1756  1660938        45  롯데백화점 강남점    276  배(신고)  1봉(1.85kg)  8166.666667
# 1888  1663243        45  롯데백화점 강남점    276  배(신고)  1봉(1.85kg)  8166.666667
# 2471  1674421        45  롯데백화점 강남점    276  배(신고)  1봉(1.85kg)  8166.666667
# 2940  1682735        45  롯데백화점 강남점    276  배(신고)  1봉(1.85kg)  8166.666667
# ...

# %%
list=['1봉(1.9kg)', '1봉(1.95kg)', '1봉(2kg)']
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/3.25)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호   시장/마트 이름  품목 번호  품목 이름       실판매규격        가격(원)  \
# 170   1634163        45  롯데백화점 강남점    276  배(신고)   1봉(1.9kg)  7538.461538
# 218   1634982        45  롯데백화점 강남점    276  배(신고)   1봉(1.9kg)  7538.461538
# 381   1637775        45  롯데백화점 강남점    276  배(신고)   1봉(1.9kg)  7538.461538
# 499   1639342        45  롯데백화점 강남점    276  배(신고)   1봉(1.9kg)  7538.461538
# 579   1640833        45  롯데백화점 강남점    276  배(신고)   1봉(1.9kg)  7538.461538
# 581   1640867        44    이마트 역삼점    276  배(신고)     1봉(2kg)  4861.538462
# ...

# %%
list=['1봉(1.45kg)',  '1봉(1.4kg)','1개(1.4kg)']
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/2)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호  품목 이름       실판매규격   가격(원)     년도-월  \
# 84    1632703        44  이마트 역삼점    276  배(신고)  1봉(1.45kg)  6400.0  2021-01
# 230   1635182        42  이마트 가양점    276  배(신고)   1봉(1.4kg)  5900.0  2021-01
# 483   1639071        42  이마트 가양점    276  배(신고)   1봉(1.4kg)  6250.0  2021-02
# 619   1641588        42  이마트 가양점    276  배(신고)   1봉(1.4kg)  6400.0  2021-02
# 755   1643977        42  이마트 가양점    276  배(신고)   1봉(1.4kg)  6400.0  2021-02
# 860   1645679        42  이마트 가양점    276  배(신고)   1봉(1.4kg)  6400.0  2021-03
# ...

# %%
list=['1팩(2.2kg)', '1봉(2.2kg)','1봉(2.1kg)']
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/3.6)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호  품목 이름      실판매규격        가격(원)  \
# 560   1640511        42  이마트 가양점    276  배(신고)  1팩(2.2kg)  5527.777778
# 1977  1664796        44  이마트 역삼점    276  배(신고)  1봉(2.2kg)  4138.888889
# 2172  1668049        44  이마트 역삼점    276  배(신고)  1봉(2.1kg)  4694.444444
# 2256  1669472        44  이마트 역삼점    276  배(신고)  1봉(2.2kg)  4694.444444
# 2473  1674455        44  이마트 역삼점    276  배(신고)  1봉(2.2kg)  4694.444444
#
#          년도-월          비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 560   2021-02  국내산,제수용3개입                  2              대형마트  500000    강서구
# 1977  2021-05     국내산 4개입                  2              대형마트  680000    강남구
# 2172  2021-06      국내산 4개                  2              대형마트  680000    강남구
# 2256  2021-06     국내산 4개입                  2              대형마트  680000    강남구
# 2473  2021-06     국내산 4개입                  2              대형마트  680000    강남구
#
#             점검일자
# 560   2021-02-25
# 1977  2021-05-27
# ...

# %%
#  '1박스(3000g)'
c = (배_276['실판매규격']==  '1박스(3000g)')
index = [배_276[c].index]
for i in index:
    배_276.loc[i, '가격(원)'] = (배_276.loc[i, '가격(원)']/5)
    배_276.loc[i, '가격(원)'] = 배_276.loc[i, '가격(원)'].astype('int')
배_276[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호  품목 이름       실판매규격   가격(원)     년도-월  \
# 4162  1704239        94  홈플러스 면목점    276  배(신고)  1박스(3000g)  2598.0  2021-10
# 4268  1708668        94  홈플러스 면목점    276  배(신고)  1박스(3000g)  2798.0  2021-11
#
#                비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 4162  국내산 신고 4-7개                  2              대형마트  260000    중랑구
# 4268  국내산 신고 4-7개                  2              대형마트  260000    중랑구
#
#             점검일자
# 4162  2021-10-28
# 4268  2021-11-18

# %%
# '1봉(1kg)'
c = (배_276['실판매규격']== '1봉(1kg)')
index = [배_276[c].index]
for i in index:
    배_276.loc[i, '가격(원)'] = (배_276.loc[i, '가격(원)']/1.6)
    배_276.loc[i, '가격(원)'] = 배_276.loc[i, '가격(원)'].astype('int')
배_276[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호  품목 이름    실판매규격   가격(원)     년도-월  \
# 1112  1650085        44  이마트 역삼점    276  배(신고)  1봉(1kg)  6237.0  2021-03
# 1150  1650739        42  이마트 가양점    276  배(신고)  1봉(1kg)  6237.0  2021-03
# 1233  1651971        42  이마트 가양점    276  배(신고)  1봉(1kg)  5562.0  2021-04
# 1361  1654210        42  이마트 가양점    276  배(신고)  1봉(1kg)  5562.0  2021-04
# 1383  1654583        44  이마트 역삼점    276  배(신고)  1봉(1kg)  5562.0  2021-04
# 1490  1656426        44  이마트 역삼점    276  배(신고)  1봉(1kg)  5562.0  2021-04
# ...

# %%
list=['1봉지4개', '1봉(4개)']
d = (배_276['실판매규격'].isin(list))
배_276.loc[d,'가격(원)'] = (배_276.loc[d,'가격(원)']/4)
배_276.loc[d,'가격(원)'].astype('int')
배_276[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호  품목 이름   실판매규격   가격(원)     년도-월  \
# 2448  1674031       214  이마트 목동점    276  배(신고)   1봉지4개  4225.0  2021-06
# 3037  1684465       129    태평백화점    276  배(신고)  1봉(4개)  4950.0  2021-08
# 3063  1684991       129    태평백화점    276  배(신고)  1봉(4개)  4950.0  2021-08
# 3127  1686211       129    태평백화점    276  배(신고)  1봉(4개)  4950.0  2021-08
# 3217  1687872       129    태평백화점    276  배(신고)  1봉(4개)  2200.0  2021-08
# 3311  1689605       129    태평백화점    276  배(신고)  1봉(4개)  2450.0  2021-08
# ...

# %%
#품목번호 284 -> 바꿀 필요 없음 
p6 = (배['품목 번호'] == 284)
배_284 = 배[p6]

# %%
#품목 번호 306
p7 = (배['품목 번호'] == 306)
배_306 = 배[p7]
배[p7]['실판매규격'].unique()
# Out:
# array(['1개', '1바스 4~6개', '1팩 3개', '1개(645g)', '1봉(1983g)3개', '1개(643g)',
#        '1개(640g)', '1개620g', '1개640g', '1개615g ', '1개600g', '1봉(4개)',
#        '1개(783g)', '600g', '1개 (2개 팩 19,000원)', '1개 ',
#        '1개 (1박스 5개 16,900원)', '1팩 2개', '1봉(1913g)3개', '1개(641g)',
#        '1개(607g)', '630g', '590g', '1개(350g)', '1개(400g)',
#        '1개 (1봉 2개 10,000원)', '1개610g ', '1봉(1927g)3개', '1개(651g)',
#        '1개(650g)', '1개 (1봉 2개 18,000원)', '1개 (1박스 5개 15,600원)',
#        '1봉(1845g)3개', '1개(609g)', '610g', '580g', '1봉(2.5k)',
#        '1개 (1팩 2개 20,000원)', '1개 (1팩 3개 11,800원)', '1봉(1806g)3개',
#        '1개(649g)', '1개(648g)', '1개640g ', '1개600', '1개(832g)',
#        '1개 (3개 29,000원)', '1개 (5개 박스 24,000원)', '1개 (3입 팩 18,000원)',
#        '1봉(1926g)3개', '1개(635g)', '1개(659g)', '1개(837g)', '1봉(3개)',
#        '1개 (3개 팩 18,000원)', '1개 (1팩 3개 15,800원)', '1개 (1팩 2개 18,000원)',
#        '1개 (2개 8,980원)', '1봉(1926g)5개', '1개(623g)', '1개(655g)',
# ...

# %%
list=['1팩 3개',  '1봉(1983g)3개','1봉(1913g)3개','1봉(1927g)3개',  '1봉(1845g)3개', '1봉(1806g)3개',  '1봉(1926g)3개',  '1봉(3개)',
     '1봉(1999g)3개','1봉(2kg)3개',  '1봉(1998g)3개', '1봉(1700g)3개','1봉(1.7kg)3개','1봉(1857g)3개', '1봉(1744g)3개',  '1개(563g)3개', 
      '1팩3개','1팩(1.7kg)3개', '1팩(1847g)3개', '1팩(1857g)3개']
d = (배_306['실판매규격'].isin(list))
배_306.loc[d,'가격(원)'] = (배_306.loc[d,'가격(원)']/3)
배_306.loc[d,'가격(원)'].astype('int')
배_306[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호      시장/마트 이름  품목 번호        품목 이름        실판매규격  \
# 10    1631443        10          용문시장    306  배(신고, 600g)        1팩 3개
# 12    1631477        63  농협 하나로마트 용산점    306  배(신고, 600g)        1팩 3개
# 22    1631647        86     홈플러스 동대문점    306  배(신고, 600g)  1봉(1983g)3개
# 112   1633179        63  농협 하나로마트 용산점    306  배(신고, 600g)        1팩 3개
# 121   1633332        86     홈플러스 동대문점    306  배(신고, 600g)  1봉(1913g)3개
# ...       ...       ...           ...    ...          ...          ...
# ...

# %%
list=['1봉(4개)', '1봉(2.5k)', '1봉지(2.5kg)', '봉(4개)','1봉(3kg)4개',  '1팩 4개', '팩 4개',  '1망(4개)']
d = (배_306['실판매규격'].isin(list))
배_306.loc[d,'가격(원)'] = (배_306.loc[d,'가격(원)']/4)
배_306.loc[d,'가격(원)'].astype('int')
배_306[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호     시장/마트 이름  품목 번호        품목 이름       실판매규격   가격(원)  \
# 69    1632450       129        태평백화점    306  배(신고, 600g)      1봉(4개)  3950.0
# 158   1633961       129        태평백화점    306  배(신고, 600g)      1봉(4개)  3450.0
# 293   1636278       129        태평백화점    306  배(신고, 600g)      1봉(4개)  4200.0
# 354   1637309       123    홈플러스 월드컵점    306  배(신고, 600g)    1봉(2.5k)  3997.5
# 372   1637623       129        태평백화점    306  배(신고, 600g)      1봉(4개)  4200.0
# 486   1639122       129        태평백화점    306  배(신고, 600g)      1봉(4개)  4200.0
# ...

# %%
list=[ '1팩 2개','1팩(997g)2개' ]
d = (배_306['실판매규격'].isin(list))
배_306.loc[d,'가격(원)'] = (배_306.loc[d,'가격(원)']/2)
배_306.loc[d,'가격(원)'].astype('int')
배_306[d]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호    시장/마트 이름  품목 번호        품목 이름       실판매규격   가격(원)  \
# 110   1633145         6     이마트 용산점    306  배(신고, 600g)       1팩 2개  3990.0
# 111   1633162        10        용문시장    306  배(신고, 600g)       1팩 2개  2850.0
# 206   1634779         6     이마트 용산점    306  배(신고, 600g)       1팩 2개  3990.0
# 313   1636616         6     이마트 용산점    306  배(신고, 600g)       1팩 2개  6450.0
# 314   1636633        10        용문시장    306  배(신고, 600g)       1팩 2개  2850.0
# 439   1638251         6     이마트 용산점    306  배(신고, 600g)       1팩 2개  6450.0
# ...

# %%
# '1바스 4~6개'
c = (배_306['실판매규격']== '1바스 4~6개')
index = [배_306[c].index]
for i in index:
    배_306.loc[i, '가격(원)'] = (배_306.loc[i, '가격(원)']/4)
    배_306.loc[i, '가격(원)'] = 배_306.loc[i, '가격(원)'].astype('int')
배_306[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#       일련번호  시장/마트 번호 시장/마트 이름  품목 번호        품목 이름     실판매규격   가격(원)     년도-월  \
# 9  1631426         6  이마트 용산점    306  배(신고, 600g)  1바스 4~6개  4225.0  2021-01
#
#           비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름        점검일자
# 9  국민의 힘  신고                  2              대형마트  170000    용산구  2021-01-28

# %%
#'1봉(1926g)5개'
c = (배_306['실판매규격']== '1봉(1926g)5개')
index = [배_306[c].index]
for i in index:
    배_306.loc[i, '가격(원)'] = (배_306.loc[i, '가격(원)']/5)
    배_306.loc[i, '가격(원)'] = 배_306.loc[i, '가격(원)'].astype('int')
배_306[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         일련번호  시장/마트 번호   시장/마트 이름  품목 번호        품목 이름        실판매규격   가격(원)  \
# 650  1642178        86  홈플러스 동대문점    306  배(신고, 600g)  1봉(1926g)5개  3598.0
#
#         년도-월   비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 650  2021-02  국내산                  2              대형마트  230000   동대문구
#
#            점검일자
# 650  2021-02-25

# %%
#'1팩 4~7개'
c = (배_306['실판매규격']== '1팩 4~7개')
index = [배_306[c].index]
for i in index:
    배_306.loc[i, '가격(원)'] = (배_306.loc[i, '가격(원)']/4)
    배_306.loc[i, '가격(원)'] = 배_306.loc[i, '가격(원)'].astype('int')
배_306[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호        품목 이름    실판매규격   가격(원)  \
# 3074  1685178         6  이마트 용산점    306  배(신고, 600g)  1팩 4~7개  4225.0
#
#          년도-월        비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 3074  2021-08  국민의힘 원황배                  2              대형마트  170000    용산구
#
#             점검일자
# 3074  2021-08-26

# %%
#'1팩 4~6개'
c = (배_306['실판매규격']== '1팩 4~6개')
index = [배_306[c].index]
for i in index:
    배_306.loc[i, '가격(원)'] = (배_306.loc[i, '가격(원)']/4)
    배_306.loc[i, '가격(원)'] = 배_306.loc[i, '가격(원)'].astype('int')
배_306[c]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호        품목 이름    실판매규격   가격(원)  \
# 3162  1686839         6  이마트 용산점    306  배(신고, 600g)  1팩 4~6개  3725.0
#
#          년도-월       비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 3162  2021-08  국내산 원황배                  2              대형마트  170000    용산구
#
#             점검일자
# 3162  2021-08-26

# %%
#품목번호 307 -> drop
p8 = (배['품목 번호'] == 307)
배[p8]
# Out:
#          일련번호  시장/마트 번호      시장/마트 이름  품목 번호        품목 이름            실판매규격  \
# 4686  1712531        85          경동시장    307  배(신고, 600g)       1포기(3.5kg)
# 4726  1713208       108         남구로시장    307        배(신고)              1포기
# 4745  1713564        44       이마트 역삼점    307        배(신고)              1포기
# 4756  1713768        63  농협 하나로마트 용산점    307        배(신고)              1포기
# 4757  1713785        62          후암시장    307  배(신고, 600g)              1포기
# 4758  1713802         6       이마트 용산점    307            배              1포기
# 4759  1713819        10          용문시장    307  배(신고, 600g)              1포기
# 4760  1713835        13        돈암제일시장    307  배(신고, 600g)  1포기  (2,5 ~3kg)
# 4825  1715092       219          대조시장    307            배              1포기
# 4826  1715109        49          대림시장    307        배(신고)              1포기
#
#       가격(원)     년도-월                          비고  시장유형 구분(시장/마트) 코드  \
# 4686   5000  2021-12                         국내산                  1
# ...

# %%
#유효한 데이터 concat 배_27, 배_248, 배_276, 배_284
clean_배 = pd.concat([배_27, 배_248, 배_276, 배_284])
clean_배['품목 번호'].value_counts()
# Out:
# 27     1258
# 276     887
# 284     212
# 248     192
# Name: 품목 번호, dtype: int64

# %%
#유효 데이터 내보내기 
clean_배.to_csv('clean_배.csv',index=False, header=True, encoding='euc-kr')

# %%
#클린 데이터 가져오기

# %%
cl_배 = pd.read_csv('clean_배.csv', encoding='euc-kr')

# %%
cl_배
# Out:
#          일련번호  시장/마트 번호  시장/마트 이름  품목 번호  품목 이름       실판매규격   가격(원)     년도-월  \
# 0     1636108       226  롯데마트 구로점     27      배   1개 (600g)  1590.0  2021-01
# 1     1631698        91      동원시장     27      배  1박스(2500g)  3725.0  2021-01
# 2     1631714        94  홈플러스 면목점     27      배  1박스(2650g)  3847.0  2021-01
# 3     1631730        90      우림시장     27      배  1박스(2500g)  3846.0  2021-01
# 4     1631746        92   이마트 상봉점     27      배  1박스(2650g)  3618.0  2021-01
# ...       ...       ...       ...    ...    ...         ...     ...      ...
# 2544  1720054       199    서울중앙시장    284  배(중품)          1개  3500.0  2021-12
# 2545  1720071        11     남대문시장    284  배(중품)          1개  4000.0  2021-12
# 2546  1721956        60   이마트 청계점    284  배(중품)          1개  4200.0  2021-12
# 2547  1721989       199    서울중앙시장    284  배(중품)          1개  3500.0  2021-12
# 2548  1722022        11     남대문시장    284  배(중품)          1개  4000.0  2021-12
#
# ...

# %%
#배 품목 이름 통일

# %%
cl_배['품목 이름'].value_counts()
# Out:
# 배              1258
# 배(신고)           887
# 배(중품)           212
# 배(신고),중급(대)     192
# Name: 품목 이름, dtype: int64

# %%
name = ['배(신고)', '배(중품)', '배(신고),중급(대)' ]

# %%
cl_배['품목 이름'] = cl_배['품목 이름'].replace(name, '배')

# %%
cl_배['품목 이름'].value_counts()
# Out:
# 배    2549
# Name: 품목 이름, dtype: int64

# %%
#가격 int로 변경 
cl_배['가격(원)'] = cl_배['가격(원)'].astype('int')

# %%
cl_배.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2549 entries, 0 to 2548
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   일련번호               2549 non-null   int64
#  1   시장/마트 번호           2549 non-null   int64
#  2   시장/마트 이름           2549 non-null   object
#  3   품목 번호              2549 non-null   int64
#  4   품목 이름              2549 non-null   object
#  5   실판매규격              2549 non-null   object
#  6   가격(원)              2549 non-null   int32
#  7   년도-월               2549 non-null   object
#  8   비고                 2538 non-null   object
#  9   시장유형 구분(시장/마트) 코드  2549 non-null   int64
#  10  시장유형 구분(시장/마트) 이름  2549 non-null   object
#  11  자치구 코드             2549 non-null   int64
#  12  자치구 이름             2549 non-null   object
#  13  점검일자               2549 non-null   object
# dtypes: int32(1), int64(5), object(8)
# memory usage: 269.0+ KB

# %%
#이상치 수정 
c= cl_배['가격(원)'] == 61400
cl_배[c]
# Out:
#          일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름      실판매규격  가격(원)     년도-월  \
# 1794  1680921        42  이마트 가양점    276     배  1팩(1.2kg)  61400  2021-07
#
#               비고  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드 자치구 이름  \
# 1794  국내산,저탄소배2개                  2              대형마트  500000    강서구
#
#             점검일자
# 1794  2021-07-29

# %%
cl_배.loc[1794,'가격(원)'] = (cl_배.loc[1794,'가격(원)']/2)

# %%
cl_배['가격(원)'].max()
# Out:
# 30700

# %%
#이름 통일한 데이터 내보내기 
cl_배.to_csv('fin_배.csv',index=False, header=True, encoding='euc-kr')
